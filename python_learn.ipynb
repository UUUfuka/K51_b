# %% [markdown]
# ![image.png](attachment:f95a9a50-6757-49e0-bbda-133b7915157b.png)

# %%
print(f'H M parameters for door')
H=float(input(f'input H'))
M=float(input("input M"))
print(f'A B C parametrs for box')
A=float(input("input A"))
B=float(input("input B"))
C=float(input("input C"))

scip_par=max(A,B,C) #max param in pox proection (A,B) or (B,C) or (A,C) we need choise optimal plane
print(scip_par)
if scip_par ==A:
    print(f'var 1')
    if B>=H and C>=M:
        print(f'Neprohod')
    elif B>=H:
        if B>=M:
             print(f'Neprohod')
        else:
            if C>=H:
                print(f'Neprohod')
            else:
                print(f'Prodhod!!')
    elif C>=M:
        if C>=H:print(f'Neprohod')
        else:
            if B>=M:
                print(f'Neprohod')
            else:print(f'Prohod!!')
    else:
        print(f'prohod!!')
elif scip_par==B:
    print(f'var 2')
    if A>=H and C>=M:
        print(f'Neprohod')
    elif A>=H:
        if A>=M:
             print(f'Neprohod')
        else:
            if C>=H:
                print(f'Neprohod')
            else:
                print(f'Prodhod!!')
    elif C>=M:
        if C>=H:print(f'Neprohod')
        else:
            if A>=M:
                print(f'Neprohod')
            else:print(f'Prohod!!')
    else:
        print(f'prohod!!')
elif scip_par==C:
    print(f'var 3')
    if B>=H and A>=M:
        print(f'Neprohod')
    elif B>=H:
        if B>=M:
             print(f'Neprohod')
        else:
            if A>=H:
                print(f'Neprohod')
            else:
                print(f'Prodhod!!')
    elif A>=M:
        if A>=H:print(f'Neprohod')
        else:
            if B>=M:
                print(f'Neprohod')
            else:print(f'Prohod!!')
    else:
        print(f'prohod!!')
# Out:
# H M parameters for door
# input H 15
# input M 12
# A B C parametrs for box
# input A 52
# input B 11
# input C 13
# 52.0
# var 1
# Prohod!!

# %% [markdown]
# ![image.png](attachment:9afe2202-d262-45da-a535-06fd2c276aa4.png)

# %%
import numpy as np
def yrov(x):
    A=1.24*np.power(x,5)
    B=0.12689*np.power(x,2)
    C=-100.45*x
    D=-36.235
    return A+B+C+D
f0=yrov(0)
for i in range(1,100):
    if yrov(i)*f0<0:
        gran=i
        break
gran
# Out:
# 4

# %%
x0=3
x1=4
while x0-x1>0.04:
    x01=(x1_x0)/2
    if yrov(x0)*yrov(x01)<0:
        x1=x01
    elif yrov(x0)*yrov(x01)>0:
        x0=x01
print(f'root is {(x0+x1)/2}')
# Out:
# root is 3.5

# %%
from random import randint
k=input()
while k!='q':
    print(randint(1,6))
    k=input()
# Out:
#  q

# %%
from random import random
coun=0
for i in range(1,int(1.e5)):
    coun=coun+random()
print(coun/1.e5)
# Out:
# 0.5016062828415455

# %%
def posl(n):
